# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./book_snapshot_5/deribit_book_snapshot_5_2020-01-01_BTC-PERPETUAL.csv.gz", header=0)

# %%
df.head()
# Out:
#     local_timestamp  bids[0].price  bids[0].amount  asks[0].price  \
# 0  1577836800050000    1000.000000           200.0    1001.000000
# 1  1577836800100000     999.442283           200.0    1000.442283
# 2  1577836800150000            NaN             NaN            NaN
# 3  1577836800200000            NaN             NaN            NaN
# 4  1577836800250000            NaN             NaN            NaN
#
#    asks[0].amount  bids[1].price  bids[1].amount  asks[1].price  \
# 0           300.0     999.500000           300.0    1001.500000
# 1           400.0            NaN             NaN            NaN
# 2             NaN     998.942283           500.0    1000.942283
# 3             NaN            NaN             NaN            NaN
# 4             NaN            NaN             NaN            NaN
#
#    asks[1].amount  bids[2].price  ...  asks[2].price  asks[2].amount  \
# 0           200.0     998.500000  ...    1002.000000           600.0
# ...

# %%
df.loc[df.index[2], "bids[0].price"] = 999

# %%
df.head()
# Out:
#     local_timestamp  bids[0].price  bids[0].amount  asks[0].price  \
# 0  1577836800050000     999.000000           200.0    1001.000000
# 1  1577836800100000     999.442283           200.0    1000.442283
# 2  1577836800150000     999.000000             NaN            NaN
# 3  1577836800200000            NaN             NaN            NaN
# 4  1577836800250000            NaN             NaN            NaN
#
#    asks[0].amount  bids[1].price  bids[1].amount  asks[1].price  \
# 0           300.0     999.500000           300.0    1001.500000
# 1           400.0            NaN             NaN            NaN
# 2             NaN     998.942283           500.0    1000.942283
# 3             NaN            NaN             NaN            NaN
# 4             NaN            NaN             NaN            NaN
#
#    asks[1].amount  bids[2].price  ...  asks[2].price  asks[2].amount  \
# 0           200.0     998.500000  ...    1002.000000           600.0
# ...
